# %% [markdown]
# ### Load env variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\notebooks

# %%
import os
print(os.listdir())
# Out:
# ['1_basic_langchain_with_gemini.ipynb']

# %%
from dotenv import load_dotenv

load_dotenv(".env")
# or
load_dotenv(r"C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\.env")
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",
    temperature=0,
    max_output_tokens=50,
    google_api_key=os.getenv("GEMINI_API_KEY"))

# %%
response = llm.invoke("What is Generative AI in 2 line?")
print(response.content)
# Out:
# Generative AI is a type of artificial intelligence that learns patterns from vast datasets.
# It then generates new, original content such as text, images, code, or music.

# %%
response = llm.invoke("tell me about india in 3 line")
print(response.content)
# Out:
# India is a vast and incredibly diverse South Asian nation, the world's most populous democracy, rich in cultures, languages, and religions.
# It boasts an ancient civilization with a profound spiritual heritage, known for its vibrant traditions, art, philosophy, and historical monuments.
# Today, India is a rapidly growing economy and a global technology hub, balancing its deep-rooted traditions with modern progress and significant challenges.

# %% [markdown]
# ### Static Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",
    temperature=0,
    google_api_key=os.getenv("GEMINI_API_KEY"))

# %%
prompts = [
    ("system","You are a python developer"),
    ("user","how to sort a array in 3 line")
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# In Python, what you typically refer to as an "array" is usually a `list`. Python offers very concise ways to sort lists. Here are two common methods, each achievable in 3 lines:
#
# ---
#
# ### Method 1: Sorting a list **in-place** (modifies the original list)
#
# This uses the `list.sort()` method.
#
# ```python
# # Line 1: Define your list (the "array")
# my_list = [5, 2, 8, 1, 9, 3]
#
# # Line 2: Sort the list in-place
# my_list.sort()
#
# # Line 3: Print the sorted list
# print(my_list)
# ```
#
# **Output:**
# ```
# [1, 2, 3, 5, 8, 9]
# ```
#
# ---
#
# ### Method 2: Creating a **new sorted list** (leaves the original list unchanged)
#
# This uses the built-in `sorted()` function.
#
# ```python
# # Line 1: Define your original list (the "array")
# original_list = [5, 2, 8, 1, 9, 3]
#
# # Line 2: Create a new sorted list from the original
# sorted_list = sorted(original_list)
#
# # Line 3: Print the new sorted list
# print(sorted_list)
# ```
#
# **Output:**
# ```
# [1, 2, 3, 5, 8, 9]
# ```
#
# **Note:** If you were to print `original_list` after this, it would still be `[5, 2, 8, 1, 9, 3]`.
#
# ---
#
# Both methods effectively sort your "array" (list) in 3 lines of code!
