# %%
import os
from dotenv import load_dotenv

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-pro",
    temperature=0,
    google_api_key=os.getenv("GEMINI_API_KEY"))

# %%
# !pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (1.1.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-groq) (1.4.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.13.4)
# Requirement already satisfied: sniffio in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.18)
# Requirement already satisfied: certifi in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.8.9)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.7.0)

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# Use the explicitly supported stable API identifier
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash-8b", 
    temperature=0,
    google_api_key=os.getenv("GEMINI_API_KEY")
)

# %%
prompts = [
    {"role":"system","content":"you are a translator , translate in hindi"},
    {"role":"user","content":"i love u so much "},
    
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\langchain_google_genai\chat_models.py:3194, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3193 try:
# -> 3194     response: GenerateContentResponse = self.client.models.generate_content(
#    3195         **request,
#    3196     )
#    3197 except ClientError as e:
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\google\genai\models.py:6480, in Models.generate_content(self, model, contents, config)
#    6479 i += 1
# -> 6480 response = self._generate_content(
#    6481     model=model, contents=contents, config=parsed_config
#    6482 )
#    6484 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\google\genai\models.py:4916, in Models._generate_content(self, model, contents, config)
#    4914 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4916 response = self._api_client.request(
#    4917     'post', path, request_dict, http_options
#    4918 )
#    4920 if config is not None and getattr(
#    4921     config, 'should_return_http_response', None
#    4922 ):
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\google\genai\_api_client.py:1611, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1608 http_request = self._build_request(
#    1609     http_method, path, request_dict, http_options
#    1610 )
# -> 1611 response = self._request(http_request, http_options, stream=False)
#    1612 response_body = (
#    1613     response.response_stream[0] if response.response_stream else ''
#    1614 )
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\google\genai\_api_client.py:1402, in BaseApiClient._request(self, http_request, http_options, stream)
#    1401     retry = tenacity.Retrying(**retry_kwargs)
# -> 1402     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1404 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\google\genai\_api_client.py:1381, in BaseApiClient._request_once(self, http_request, stream)
#    1380   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1381 errors.APIError.raise_for_response(response)
#    1382 return HttpResponse(
#    1383     response.headers, response if stream else [response.text]
#    1384 )
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash-8b is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[3], line 7
#       3     {"role":"user","content":"i love u so much "},
#       4
#       5 ]
#       6
# ----> 7 res = llm.invoke(prompts)
#       8 print(res.content)
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\langchain_google_genai\chat_models.py:2672, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2669         msg = "Tools are already defined.code_execution tool can't be defined"
#    2670         raise ValueError(msg)
# -> 2672 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1847, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1838 @override
#    1839 def generate_prompt(
#    1840     self,
#    (...)   1844     **kwargs: Any,
#    1845 ) -> LLMResult:
#    1846     prompt_messages = [p.to_messages() for p in prompts]
# -> 1847     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1654, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1651 for i, m in enumerate(input_messages):
#    1652     try:
#    1653         results.append(
# -> 1654             self._generate_with_cache(
#    1655                 m,
#    1656                 stop=stop,
#    1657                 run_manager=run_managers[i] if run_managers else None,
#    1658                 **kwargs,
#    1659             )
#    1660         )
#    1661     except BaseException as e:
#    1662         if run_managers:
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\langchain_google_genai\chat_models.py:3198, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3194     response: GenerateContentResponse = self.client.models.generate_content(
#    3195         **request,
#    3196     )
#    3197 except ClientError as e:
# -> 3198     _handle_client_error(e, request)
#    3200 return _response_to_result(response)
#
# File c:\Users\HELLO\OneDrive\Desktop\GEN_AI_series\myenv\Lib\site-packages\langchain_google_genai\chat_models.py:169, in _handle_client_error(e, request)
#     167 model_name = request.get("model", "unknown")
#     168 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 169 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-1.5-flash-8b' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash-8b is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %% [markdown]
# ### Prompt Templates - Dynamic Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",
    temperature=0,
    code_execution=True,
    google_api_key=os.getenv("GEMINI_API_KEY"))
# Out:
# Unexpected argument 'code_execution' provided to ChatGoogleGenerativeAI.

# %%
# prompts = ChatPromptTemplate.from_messages(
#     [
#     {"role":"system","content":"you are a translator , translate in {language}"},
#     {"role":"user","content":"{query} "}
#     ]
# )

# %%
#

# %% [markdown]
# ### Chains - Runnable
# #### Runnable = function or data that can be invokes

# %%
# res = llm.invoke(prompts.invoke({
#     "language":"hindi",
#     "query":"i love you"
# }))
# res.content

# %%
chains = prompts | llm

# %%
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# Initialize the Groq LLM with a supported model
llm_groq = ChatGroq(
    model="llama-3.3-70b-versatile",  # <-- Updated to a supported Llama 3.1 version
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY") 
)
out = StrOutputParser()

# %%
def transform_case(result:str):
    return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role": "system", "content": "you are a translator, translate in {language}"},
    {"role": "user", "content": "{query}"}
])

# %%
chains = prompts | llm_groq | out | transform_case

res = chains.invoke({
    "language": "hinglish",
    "query": "hello my name is sarthak"
})

print(res)
# Out:
# NAMASTE, MERA NAAM SARTHAK HAI, AAP KAISE HO?
