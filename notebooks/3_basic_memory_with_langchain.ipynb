# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
llm = ChatGroq(
    model="llama-3.3-70b-versatile",  # <-- Updated to a supported Llama 3.1 version
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY") 
)

# %%
prompts= [
    {"role": "system", "content": "You are a helpful and polite AI programming assistant."},
    
    # Turn 1
    {"role": "user", "content": "Hello! My name is Sarthak."},
    {"role": "assistant", "content": "Namaste Sarthak! Great to meet you. How can I help you with your coding today?"},
    
    # Turn 2
    {"role": "user", "content": "What is my name?"},
    {"role": "assistant", "content": "Your name is Sarthak!"},
    
    # Turn 3 (Active Follow-up)
    {"role": "user", "content": "Can you explain what LangChain is in one sentence?"}
]

res = llm.invoke(prompts)

# %%
res.content
# Out:
# 'LangChain is an open-source framework that enables developers to build applications powered by large language models, providing a set of tools and libraries to simplify the process of integrating AI models into their projects.'

# %% [markdown]
# Manage History

# %%
history = []
while True:
    query = input("user: ")
    
    if query.lower() in ["exit","bye","quit"]:
        print("Goodbye")
        break
    

    history.append( {"role": "user", "content": query})
    print("User: ",query)
    
    res = llm.invoke(history)
    history.append( {"role": "ai", "content": res.content})
    
    print("AI: ",res.content,"\n")
# Out:
# User:
# AI:  It seems like you didn't type anything. Please go ahead and ask your question, and I'll do my best to help.
#
# User:  hi
# AI:  It's nice to meet you. Is there something I can help you with or would you like to chat?
#
# User:  who is pm in 3 word
# AI:  Prime Minister Narendra
#
# User:  his age ? in 5 word
# AI:  Narendra Modi is seventy two
#
# User:  python in 2 line
# AI:  Python is a programming language.
# It's used for web development, data analysis, and more.
#
# User:  one liner function?
# AI:  A one-liner function in Python is a function defined in a single line of code, typically using lambda functions, such as: `add = lambda x, y: x + y`
#
# Goodbye
